# %% [markdown]
# <a href="https://colab.research.google.com/github/tanaymukherjee/Debugging-NY-Times-library/blob/main/Debugging_NY_Times.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Accessing NY Times Database via Web APIs

# %%
# Import required libraries
import requests
import json
from __future__ import division
import math
import csv
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## 1. Constructing API GET Request

# %%
# set base url
base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

# %% [markdown]
# For the API key, we'll use the following demonstration key for now, but in the future, get your own, it only takes a few seconds!

# %%
# set key
key = "BBoHU8vBvJFxaeiazF1zpbwc4WKf6fwY"

# %% [markdown]
# For many API's, you'll have to specify the response format, such as xml or JSON. But for this particular API, the only possible response format is JSON, as we can see in the url, so we don't have to name it explicitly.
#
# Now we need to send some sort of data in the URL’s query string. This data tells the API what information we want. In our case, we want articles about Covid. Requests allows you to provide these arguments as a dictionary, using the params keyword argument. In addition to the search term q, we have to put in the api-key term.

# %%
# set search parameters
search_params = {"q": "Covid",
                 "api-key": key}

# %%
# make request
r = requests.get(base_url, params=search_params)

# %%
print(r.url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Covid&api-key=BBoHU8vBvJFxaeiazF1zpbwc4WKf6fwY

# %% [markdown]
# ### Challenge 1: Adding a date range
# What if we only want to search within a particular date range? The NYT Article Search API allows us to specify start and end dates.
#
# Alter search_params so that the request only searches for articles in the year 2020. Remember, since search_params is a dictionary, we can simply add the new keys to it.

# %%
# set date parameters here
search_params["begin_date"] = "20200101"
search_params["end_date"] = "20201231"

# %% [markdown]
# ### Challenge 2: Specifying a results page
# The above will return the first 10 results. To get the next ten, you need to add a "page" parameter. Change the search parameters above to get the second 10 results.

# %%
# set page parameters here
search_params["page"] = 1

# %%
r = requests.get(base_url, params=search_params)
print(r.url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Covid&api-key=BBoHU8vBvJFxaeiazF1zpbwc4WKf6fwY&begin_date=20200101&end_date=20201231&page=1

# %% [markdown]
# ## 2. Parsing the response text

# %%
# Inspect the content of the response, parsing the result as text
response_text = r.text
print(response_text[:1000])
# Out:
# {"status":"OK","copyright":"Copyright (c) 2021 The New York Times Company. All Rights Reserved.","response":{"docs":[{"abstract":"A sales executive who was placed on a ventilator while in a coma says she was denied accommodations to work from home as she recovered.","web_url":"https://www.nytimes.com/2020/12/24/business/tony-robbins-covid-lawsuit.html","snippet":"A sales executive who was placed on a ventilator while in a coma says she was denied accommodations to work from home as she recovered.","lead_paragraph":"Tony Robbins, the life coach and motivational speaker, discriminated against one of his employees by refusing to grant her the accommodations she needed to work from home after she contracted a debilitating case of Covid-19 in the spring, according to a lawsuit filed Wednesday.","print_section":"B","print_page":"5","source":"The New York Times","multimedia":[{"rank":0,"subtype":"xlarge","caption":null,"credit":null,"type":"image","url":"images/2020/12/23/lens/23xp-tonyrobbin

# %%
# Convert JSON response to a dictionary
data = json.loads(response_text)
print(data)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'abstract': 'A sales executive who was placed on a ventilator while in a coma says she was denied accommodations to work from home as she recovered.', 'web_url': 'https://www.nytimes.com/2020/12/24/business/tony-robbins-covid-lawsuit.html', 'snippet': 'A sales executive who was placed on a ventilator while in a coma says she was denied accommodations to work from home as she recovered.', 'lead_paragraph': 'Tony Robbins, the life coach and motivational speaker, discriminated against one of his employees by refusing to grant her the accommodations she needed to work from home after she contracted a debilitating case of Covid-19 in the spring, according to a lawsuit filed Wednesday.', 'print_section': 'B', 'print_page': '5', 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-articleLarge.jpg', 'height': 428, 'width': 600, 'legacy': {'xlarge': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 428}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'popup', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-popup.jpg', 'height': 463, 'width': 650, 'legacy': {}, 'subType': 'popup', 'crop_name': 'popup'}, {'rank': 0, 'subtype': 'blog480', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog480.jpg', 'height': 342, 'width': 480, 'legacy': {}, 'subType': 'blog480', 'crop_name': 'blog480'}, {'rank': 0, 'subtype': 'blog533', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog533.jpg', 'height': 380, 'width': 533, 'legacy': {}, 'subType': 'blog533', 'crop_name': 'blog533'}, {'rank': 0, 'subtype': 'blog427', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog427.jpg', 'height': 304, 'width': 427, 'legacy': {}, 'subType': 'blog427', 'crop_name': 'blog427'}, {'rank': 0, 'subtype': 'tmagSF', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-tmagSF.jpg', 'height': 258, 'width': 362, 'legacy': {}, 'subType': 'tmagSF', 'crop_name': 'tmagSF'}, {'rank': 0, 'subtype': 'tmagArticle', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-tmagArticle.jpg', 'height': 422, 'width': 592, 'legacy': {}, 'subType': 'tmagArticle', 'crop_name': 'tmagArticle'}, {'rank': 0, 'subtype': 'slide', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-slide.jpg', 'height': 428, 'width': 600, 'legacy': {}, 'subType': 'slide', 'crop_name': 'slide'}, {'rank': 0, 'subtype': 'jumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-jumbo.jpg', 'height': 730, 'width': 1024, 'legacy': {}, 'subType': 'jumbo', 'crop_name': 'jumbo'}, {'rank': 0, 'subtype': 'superJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-superJumbo.jpg', 'height': 1460, 'width': 2048, 'legacy': {}, 'subType': 'superJumbo', 'crop_name': 'superJumbo'}, {'rank': 0, 'subtype': 'blog225', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog225.jpg', 'height': 160, 'width': 225, 'legacy': {}, 'subType': 'blog225', 'crop_name': 'blog225'}, {'rank': 0, 'subtype': 'master105 ...

# %%
print(data.keys())
# Out:
# dict_keys(['status', 'copyright', 'response'])

# %%
data['copyright']
# Out:
# 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.'

# %%
data['response'].keys()
# Out:
# dict_keys(['docs', 'meta'])

# %%
print(data['response']['docs'])
# Out:
# [{'abstract': 'A sales executive who was placed on a ventilator while in a coma says she was denied accommodations to work from home as she recovered.', 'web_url': 'https://www.nytimes.com/2020/12/24/business/tony-robbins-covid-lawsuit.html', 'snippet': 'A sales executive who was placed on a ventilator while in a coma says she was denied accommodations to work from home as she recovered.', 'lead_paragraph': 'Tony Robbins, the life coach and motivational speaker, discriminated against one of his employees by refusing to grant her the accommodations she needed to work from home after she contracted a debilitating case of Covid-19 in the spring, according to a lawsuit filed Wednesday.', 'print_section': 'B', 'print_page': '5', 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-articleLarge.jpg', 'height': 428, 'width': 600, 'legacy': {'xlarge': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 428}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'popup', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-popup.jpg', 'height': 463, 'width': 650, 'legacy': {}, 'subType': 'popup', 'crop_name': 'popup'}, {'rank': 0, 'subtype': 'blog480', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog480.jpg', 'height': 342, 'width': 480, 'legacy': {}, 'subType': 'blog480', 'crop_name': 'blog480'}, {'rank': 0, 'subtype': 'blog533', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog533.jpg', 'height': 380, 'width': 533, 'legacy': {}, 'subType': 'blog533', 'crop_name': 'blog533'}, {'rank': 0, 'subtype': 'blog427', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog427.jpg', 'height': 304, 'width': 427, 'legacy': {}, 'subType': 'blog427', 'crop_name': 'blog427'}, {'rank': 0, 'subtype': 'tmagSF', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-tmagSF.jpg', 'height': 258, 'width': 362, 'legacy': {}, 'subType': 'tmagSF', 'crop_name': 'tmagSF'}, {'rank': 0, 'subtype': 'tmagArticle', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-tmagArticle.jpg', 'height': 422, 'width': 592, 'legacy': {}, 'subType': 'tmagArticle', 'crop_name': 'tmagArticle'}, {'rank': 0, 'subtype': 'slide', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-slide.jpg', 'height': 428, 'width': 600, 'legacy': {}, 'subType': 'slide', 'crop_name': 'slide'}, {'rank': 0, 'subtype': 'jumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-jumbo.jpg', 'height': 730, 'width': 1024, 'legacy': {}, 'subType': 'jumbo', 'crop_name': 'jumbo'}, {'rank': 0, 'subtype': 'superJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-superJumbo.jpg', 'height': 1460, 'width': 2048, 'legacy': {}, 'subType': 'superJumbo', 'crop_name': 'superJumbo'}, {'rank': 0, 'subtype': 'blog225', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog225.jpg', 'height': 160, 'width': 225, 'legacy': {}, 'subType': 'blog225', 'crop_name': 'blog225'}, {'rank': 0, 'subtype': 'master1050', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbi ...

# %%
docs = data['response']['docs']

# %%
type(docs)
# Out:
# list

# %%
docs[0]
# Out:
# {'_id': 'nyt://article/297bd87d-5667-537a-a94d-7fc2fd054849',
#  'abstract': 'A sales executive who was placed on a ventilator while in a coma says she was denied accommodations to work from home as she recovered.',
#  'byline': {'organization': None,
#   'original': 'By Azi Paybarah and Michael Levenson',
#   'person': [{'firstname': 'Azi',
#     'lastname': 'Paybarah',
#     'middlename': None,
#     'organization': '',
#     'qualifier': None,
#     'rank': 1,
#     'role': 'reported',
#     'title': None},
#    {'firstname': 'Michael',
#     'lastname': 'Levenson',
#     'middlename': None,
#     'organization': '',
#     'qualifier': None,
#     'rank': 2,
#     'role': 'reported',
#     'title': None}]},
#  'document_type': 'article',
#  'headline': {'content_kicker': None,
#   'kicker': None,
#   'main': 'Lawsuit Accuses Tony Robbins of Discriminating Against Employee Who Got Covid',
#   'name': None,
#   'print_headline': 'Robbins Sued By Employee Who Had Covid',
#   'seo': None,
#   'sub': None},
#  'keywords': [{'major': 'N',
#    'name': 'subject',
#    'rank': 1,
#    'value': 'Coronavirus (2019-nCoV)'},
#   {'major': 'N',
#    'name': 'subject',
#    'rank': 2,
#    'value': 'Workplace Hazards and Violations'},
#   {'major': 'N',
#    'name': 'subject',
#    'rank': 3,
#    'value': 'Suits and Litigation (Civil)'},
#   {'major': 'N', 'name': 'persons', 'rank': 4, 'value': 'Robbins, Tony'},
#   {'major': 'N',
#    'name': 'organizations',
#    'rank': 5,
#    'value': 'Robbins Research International'}],
#  'lead_paragraph': 'Tony Robbins, the life coach and motivational speaker, discriminated against one of his employees by refusing to grant her the accommodations she needed to work from home after she contracted a debilitating case of Covid-19 in the spring, according to a lawsuit filed Wednesday.',
#  'multimedia': [{'caption': None,
#    'credit': None,
#    'crop_name': 'articleLarge',
#    'height': 428,
#    'legacy': {'xlarge': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-articleLarge.jpg',
#     'xlargeheight': 428,
#     'xlargewidth': 600},
#    'rank': 0,
#    'subType': 'xlarge',
#    'subtype': 'xlarge',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-articleLarge.jpg',
#    'width': 600},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'popup',
#    'height': 463,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'popup',
#    'subtype': 'popup',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-popup.jpg',
#    'width': 650},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blog480',
#    'height': 342,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blog480',
#    'subtype': 'blog480',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog480.jpg',
#    'width': 480},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blog533',
#    'height': 380,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blog533',
#    'subtype': 'blog533',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog533.jpg',
#    'width': 533},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blog427',
#    'height': 304,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blog427',
#    'subtype': 'blog427',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog427.jpg',
#    'width': 427},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'tmagSF',
#    'height': 258,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'tmagSF',
#    'subtype': 'tmagSF',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-tmagSF.jpg',
#    'width': 362},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'tmagArticle',
#    'height': 422,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'tmagArticle',
#    'subtype': 'tmagArticle',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-tmagArticle.jpg',
#    'width': 592},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'slide',
#    'height': 428,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'slide',
#    'subtype': 'slide',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-slide.jpg',
#    'width': 600},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'jumbo',
#    'height': 730,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'jumbo',
#    'subtype': 'jumbo',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-jumbo.jpg',
#    'width': 1024},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'superJumbo',
#    'height': 1460,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'superJumbo',
#    'subtype': 'superJumbo',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-superJumbo.jpg',
#    'width': 2048},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blog225',
#    'height': 160,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blog225',
#    'subtype': 'blog225',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blog225.jpg',
#    'width': 225},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master1050',
#    'height': 748,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master1050',
#    'subtype': 'master1050',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-master1050.jpg',
#    'width': 1050},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master675',
#    'height': 481,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master675',
#    'subtype': 'master675',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-master675.jpg',
#    'width': 675},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master495',
#    'height': 353,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master495',
#    'subtype': 'master495',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-master495.jpg',
#    'width': 495},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master180',
#    'height': 128,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master180',
#    'subtype': 'master180',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-master180.jpg',
#    'width': 180},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master315',
#    'height': 225,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master315',
#    'subtype': 'master315',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-master315.jpg',
#    'width': 315},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master768',
#    'height': 547,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master768',
#    'subtype': 'master768',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-master768.jpg',
#    'width': 768},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'thumbStandard',
#    'height': 75,
#    'legacy': {'thumbnail': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-thumbStandard.jpg',
#     'thumbnailheight': 75,
#     'thumbnailwidth': 75},
#    'rank': 0,
#    'subType': 'thumbnail',
#    'subtype': 'thumbnail',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-thumbStandard.jpg',
#    'width': 75},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blogSmallThumb',
#    'height': 50,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blogSmallThumb',
#    'subtype': 'blogSmallThumb',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blogSmallThumb.jpg',
#    'width': 50},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'thumbLarge',
#    'height': 150,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'thumbLarge',
#    'subtype': 'thumbLarge',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-thumbLarge.jpg',
#    'width': 150},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'smallSquare168',
#    'height': 168,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'smallSquare168',
#    'subtype': 'smallSquare168',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-smallSquare168.jpg',
#    'width': 168},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'smallSquare252',
#    'height': 252,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'smallSquare252',
#    'subtype': 'smallSquare252',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-smallSquare252.jpg',
#    'width': 252},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'square320',
#    'height': 320,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'square320',
#    'subtype': 'square320',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-square320.jpg',
#    'width': 320},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'moth',
#    'height': 151,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'moth',
#    'subtype': 'moth',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-moth.jpg',
#    'width': 151},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'filmstrip',
#    'height': 190,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'filmstrip',
#    'subtype': 'filmstrip',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-filmstrip.jpg',
#    'width': 190},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'square640',
#    'height': 640,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'square640',
#    'subtype': 'square640',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-square640.jpg',
#    'width': 640},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumSquare149',
#    'height': 149,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumSquare149',
#    'subtype': 'mediumSquare149',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-mediumSquare149.jpg',
#    'width': 149},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumSquareAt3X',
#    'height': 1800,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumSquareAt3X',
#    'subtype': 'mediumSquareAt3X',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-mediumSquareAt3X.jpg',
#    'width': 1800},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'sfSpan',
#    'height': 263,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'sfSpan',
#    'subtype': 'sfSpan',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-sfSpan.jpg',
#    'width': 395},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'largeHorizontal375',
#    'height': 250,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'largeHorizontal375',
#    'subtype': 'largeHorizontal375',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-largeHorizontal375.jpg',
#    'width': 375},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'largeHorizontalJumbo',
#    'height': 683,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'largeHorizontalJumbo',
#    'subtype': 'largeHorizontalJumbo',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-largeHorizontalJumbo.jpg',
#    'width': 1024},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'horizontalMediumAt2X',
#    'height': 1910,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'horizontalMediumAt2X',
#    'subtype': 'horizontalMediumAt2X',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-horizontalMediumAt2X.jpg',
#    'width': 2865},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'hpLarge',
#    'height': 288,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'hpLarge',
#    'subtype': 'hpLarge',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-hpLarge.jpg',
#    'width': 511},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'largeWidescreen573',
#    'height': 322,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'largeWidescreen573',
#    'subtype': 'largeWidescreen573',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-largeWidescreen573.jpg',
#    'width': 573},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'largeWidescreen1050',
#    'height': 591,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'largeWidescreen1050',
#    'subtype': 'largeWidescreen1050',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-largeWidescreen1050.jpg',
#    'width': 1050},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'thumbWide',
#    'height': 126,
#    'legacy': {'wide': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-thumbWide.jpg',
#     'wideheight': 126,
#     'widewidth': 190},
#    'rank': 0,
#    'subType': 'wide',
#    'subtype': 'wide',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-thumbWide.jpg',
#    'width': 190},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoThumb',
#    'height': 50,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoThumb',
#    'subtype': 'videoThumb',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoThumb.jpg',
#    'width': 75},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoLarge',
#    'height': 507,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoLarge',
#    'subtype': 'videoLarge',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoLarge.jpg',
#    'width': 768},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumThreeByTwo210',
#    'height': 140,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumThreeByTwo210',
#    'subtype': 'mediumThreeByTwo210',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-mediumThreeByTwo210.jpg',
#    'width': 210},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumThreeByTwo225',
#    'height': 150,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumThreeByTwo225',
#    'subtype': 'mediumThreeByTwo225',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-mediumThreeByTwo225.jpg',
#    'width': 225},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumThreeByTwo440',
#    'height': 293,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumThreeByTwo440',
#    'subtype': 'mediumThreeByTwo440',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-mediumThreeByTwo440.jpg',
#    'width': 440},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumThreeByTwo252',
#    'height': 168,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumThreeByTwo252',
#    'subtype': 'mediumThreeByTwo252',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-mediumThreeByTwo252.jpg',
#    'width': 252},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumThreeByTwo378',
#    'height': 252,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumThreeByTwo378',
#    'subtype': 'mediumThreeByTwo378',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-mediumThreeByTwo378.jpg',
#    'width': 378},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'threeByTwoLargeAt2X',
#    'height': 1910,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'threeByTwoLargeAt2X',
#    'subtype': 'threeByTwoLargeAt2X',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-threeByTwoLargeAt2X.jpg',
#    'width': 2865},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'threeByTwoMediumAt2X',
#    'height': 1000,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'threeByTwoMediumAt2X',
#    'subtype': 'threeByTwoMediumAt2X',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-threeByTwoMediumAt2X.jpg',
#    'width': 1500},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'threeByTwoSmallAt2X',
#    'height': 400,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'threeByTwoSmallAt2X',
#    'subtype': 'threeByTwoSmallAt2X',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-threeByTwoSmallAt2X.jpg',
#    'width': 600},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'articleInline',
#    'height': 135,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'articleInline',
#    'subtype': 'articleInline',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-articleInline.jpg',
#    'width': 190},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'hpSmall',
#    'height': 116,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'hpSmall',
#    'subtype': 'hpSmall',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-hpSmall.jpg',
#    'width': 163},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blogSmallInline',
#    'height': 108,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blogSmallInline',
#    'subtype': 'blogSmallInline',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-blogSmallInline.jpg',
#    'width': 151},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumFlexible177',
#    'height': 126,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumFlexible177',
#    'subtype': 'mediumFlexible177',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-mediumFlexible177.jpg',
#    'width': 177},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSmall',
#    'height': 281,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSmall',
#    'subtype': 'videoSmall',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSmall.jpg',
#    'width': 500},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoHpMedium',
#    'height': 211,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoHpMedium',
#    'subtype': 'videoHpMedium',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoHpMedium.jpg',
#    'width': 375},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine600',
#    'height': 338,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine600',
#    'subtype': 'videoSixteenByNine600',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine600.jpg',
#    'width': 600},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine540',
#    'height': 304,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine540',
#    'subtype': 'videoSixteenByNine540',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine540.jpg',
#    'width': 540},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine495',
#    'height': 278,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine495',
#    'subtype': 'videoSixteenByNine495',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine495.jpg',
#    'width': 495},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine390',
#    'height': 219,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine390',
#    'subtype': 'videoSixteenByNine390',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine390.jpg',
#    'width': 390},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine1050',
#    'height': 591,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine1050',
#    'subtype': 'videoSixteenByNine1050',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine1050.jpg',
#    'width': 1050},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine480',
#    'height': 270,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine480',
#    'subtype': 'videoSixteenByNine480',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine480.jpg',
#    'width': 480},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine310',
#    'height': 174,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine310',
#    'subtype': 'videoSixteenByNine310',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine310.jpg',
#    'width': 310},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine225',
#    'height': 126,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine225',
#    'subtype': 'videoSixteenByNine225',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine225.jpg',
#    'width': 225},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine96',
#    'height': 54,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine96',
#    'subtype': 'videoSixteenByNine96',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine96.jpg',
#    'width': 96},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine768',
#    'height': 432,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine768',
#    'subtype': 'videoSixteenByNine768',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine768.jpg',
#    'width': 768},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine150',
#    'height': 84,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine150',
#    'subtype': 'videoSixteenByNine150',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNine150.jpg',
#    'width': 150},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNineJumbo1600',
#    'height': 900,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNineJumbo1600',
#    'subtype': 'videoSixteenByNineJumbo1600',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoSixteenByNineJumbo1600.jpg',
#    'width': 1600},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'miniMoth',
#    'height': 70,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'miniMoth',
#    'subtype': 'miniMoth',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-miniMoth.jpg',
#    'width': 151},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'windowsTile336H',
#    'height': 336,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'windowsTile336H',
#    'subtype': 'windowsTile336H',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-windowsTile336H.jpg',
#    'width': 694},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoFifteenBySeven1305',
#    'height': 609,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoFifteenBySeven1305',
#    'subtype': 'videoFifteenBySeven1305',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoFifteenBySeven1305.jpg',
#    'width': 1305},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoFifteenBySeven2610',
#    'height': 1218,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoFifteenBySeven2610',
#    'subtype': 'videoFifteenBySeven2610',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-videoFifteenBySeven2610.jpg',
#    'width': 2610},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'facebookJumbo',
#    'height': 549,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'facebookJumbo',
#    'subtype': 'facebookJumbo',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-facebookJumbo.jpg',
#    'width': 1050},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'watch308',
#    'height': 348,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'watch308',
#    'subtype': 'watch308',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-watch308.jpg',
#    'width': 312},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'watch268',
#    'height': 304,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'watch268',
#    'subtype': 'watch268',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-watch268.jpg',
#    'width': 272},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'verticalTwoByThree735',
#    'height': 1103,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'verticalTwoByThree735',
#    'subtype': 'verticalTwoByThree735',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-verticalTwoByThree735.jpg',
#    'width': 735},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mobileMasterAt3x',
#    'height': 1283,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mobileMasterAt3x',
#    'subtype': 'mobileMasterAt3x',
#    'type': 'image',
#    'url': 'images/2020/12/23/lens/23xp-tonyrobbins-photo/23xp-tonyrobbins-photo-mobileMasterAt3x.jpg',
#    'width': 1800}],
#  'news_desk': 'Express',
#  'print_page': '5',
#  'print_section': 'B',
#  'pub_date': '2020-12-24T14:11:47+0000',
#  'section_name': 'Business Day',
#  'snippet': 'A sales executive who was placed on a ventilator while in a coma says she was denied accommodations to work from home as she recovered.',
#  'source': 'The New York Times',
#  'type_of_material': 'News',
#  'uri': 'nyt://article/297bd87d-5667-537a-a94d-7fc2fd054849',
#  'web_url': 'https://www.nytimes.com/2020/12/24/business/tony-robbins-covid-lawsuit.html',
#  'word_count': 823}

# %% [markdown]
# ## 3. Putting everything together to get all the articles.

# %%
# set key
key = "BBoHU8vBvJFxaeiazF1zpbwc4WKf6fwY"

# set base url
base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

# set search parameters
search_params = {"q": "Covid",
                 "api-key": key,
                 "begin_date": "20200101",  # date must be in YYYYMMDD format
                 "end_date": "20200131"}

# make request
r = requests.get(base_url, params=search_params)

# wait 3 seconds for the GET request
time.sleep(3)

# convert to a dictionary
data = json.loads(r.text)

# get number of hits
hits = data['response']['meta']['hits']
print("number of hits: ", str(hits))

# get number of pages
pages = int(math.ceil(hits / 10))
print("number of pages: ", str(pages))
# Out:
# number of hits:  105
# number of pages:  11

# %% [markdown]
# Now we're ready to loop through our pages. We'll start off by creating an empty list all_docs which will be our accumulator variable. Then we'll loop through pages and make a request for each one.

# %%
# make an empty list where we'll hold all of our docs for every page
all_docs = []

# now we're ready to loop through the pages
for i in range(pages):
    print("collecting page", str(i))

    # set the page parameter
    search_params['page'] = i

    # make request
    r = requests.get(base_url, params=search_params)

    # get text and convert to a dictionary
    data = json.loads(r.text)

    # get just the docs
    docs = data['response']['docs']

    # add those docs to the big list
    all_docs = all_docs + docs

    time.sleep(3)  # pause between calls
# Out:
# collecting page 0
# collecting page 1
# collecting page 2
# collecting page 3
# collecting page 4
# collecting page 5
# collecting page 6
# collecting page 7
# collecting page 8
# collecting page 9
# collecting page 10

# %% [markdown]
# Let's make sure we got all the articles.

# %%
assert len(all_docs) == data['response']['meta']['hits']

# %% [markdown]
# ### Challenge 3: Make a function
# Using the code above, create a function called get_api_data() with the parameters term and a year that returns all the documents containing that search term in that year.

# %%
#DEFINE YOUR FUNCTION HERE

def get_api_data(term, year):
    
    # set base url
    base_url = "http://api.nytimes.com/svc/search/v2/articlesearch"

    # set search parameters
    search_params = {"q": term,
                     "api-key": "BBoHU8vBvJFxaeiazF1zpbwc4WKf6fwY",
                     # date must be in YYYYMMDD format
                     "begin_date": str(year) + "0101",
                     "end_date": str(year) + "0131"}

    # make request
    r = requests.get(base_url, params=search_params)
    time.sleep(3)

    # convert to a dictionary
    data = json.loads(r.text)

    # get number of hits
    hits = data['response']['meta']['hits']
    print("number of hits:", str(hits))

    # get number of pages
    pages = int(math.ceil(hits / 10))

    # make an empty list where we'll hold all of our docs for every page
    all_docs = []

    # now we're ready to loop through the pages
    for i in range(pages):
        print("collecting page", str(i))

        # set the page parameter
        search_params['page'] = i

        # make request
        r = requests.get(base_url, params=search_params)

        # get text and convert to a dictionary
        data = json.loads(r.text)

        # get just the docs
        docs = data['response']['docs']

        # add those docs to the big list
        all_docs = all_docs + docs

        time.sleep(3)  # pause between calls

    return(all_docs)

# %%
get_api_data("Covid", 2020)

# %%
all_docs[0]
# Out:
# {'_id': 'nyt://interactive/669ba0d2-a0c6-5f87-9017-c92d47cf3b20',
#  'abstract': 'Test your knowledge of this week’s health news.',
#  'byline': {'organization': None,
#   'original': 'By Toby Bilanow',
#   'person': [{'firstname': 'Toby',
#     'lastname': 'Bilanow',
#     'middlename': None,
#     'organization': '',
#     'qualifier': None,
#     'rank': 1,
#     'role': 'reported',
#     'title': None}]},
#  'document_type': 'multimedia',
#  'headline': {'content_kicker': None,
#   'kicker': None,
#   'main': 'Weekly Health Quiz: Optimism, Muscles and Coronavirus',
#   'name': None,
#   'print_headline': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [{'major': 'N',
#    'name': 'subject',
#    'rank': 1,
#    'value': 'Coronavirus (2019-nCoV)'},
#   {'major': 'N', 'name': 'subject', 'rank': 2, 'value': "Alzheimer's Disease"},
#   {'major': 'N',
#    'name': 'subject',
#    'rank': 3,
#    'value': 'SARS (Severe Acute Respiratory Syndrome)'},
#   {'major': 'N', 'name': 'subject', 'rank': 4, 'value': 'Prostate Gland'},
#   {'major': 'N', 'name': 'subject', 'rank': 5, 'value': 'Heart'},
#   {'major': 'N', 'name': 'subject', 'rank': 6, 'value': 'Elderly'},
#   {'major': 'N', 'name': 'subject', 'rank': 7, 'value': 'Longevity'},
#   {'major': 'N',
#    'name': 'subject',
#    'rank': 8,
#    'value': 'Hygiene and Cleanliness'},
#   {'major': 'N', 'name': 'subject', 'rank': 9, 'value': 'Muscles'},
#   {'major': 'N',
#    'name': 'subject',
#    'rank': 10,
#    'value': 'Deaths (Fatalities)'},
#   {'major': 'N',
#    'name': 'subject',
#    'rank': 11,
#    'value': 'Medicine and Health'},
#   {'major': 'N', 'name': 'subject', 'rank': 12, 'value': 'Optimism'},
#   {'major': 'N', 'name': 'subject', 'rank': 13, 'value': 'Exercise'}],
#  'lead_paragraph': 'Test your knowledge of this week’s health news.',
#  'multimedia': [{'caption': None,
#    'credit': None,
#    'crop_name': 'articleLarge',
#    'height': 398,
#    'legacy': {'xlarge': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-articleLarge.jpg',
#     'xlargeheight': 398,
#     'xlargewidth': 600},
#    'rank': 0,
#    'subType': 'xlarge',
#    'subtype': 'xlarge',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-articleLarge.jpg',
#    'width': 600},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'popup',
#    'height': 431,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'popup',
#    'subtype': 'popup',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-popup.jpg',
#    'width': 650},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blog480',
#    'height': 318,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blog480',
#    'subtype': 'blog480',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-blog480.jpg',
#    'width': 480},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blog533',
#    'height': 353,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blog533',
#    'subtype': 'blog533',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-blog533.jpg',
#    'width': 533},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blog427',
#    'height': 283,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blog427',
#    'subtype': 'blog427',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-blog427.jpg',
#    'width': 427},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'tmagSF',
#    'height': 240,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'tmagSF',
#    'subtype': 'tmagSF',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-tmagSF.jpg',
#    'width': 362},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'tmagArticle',
#    'height': 392,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'tmagArticle',
#    'subtype': 'tmagArticle',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-tmagArticle.jpg',
#    'width': 592},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'slide',
#    'height': 398,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'slide',
#    'subtype': 'slide',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-slide.jpg',
#    'width': 600},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'jumbo',
#    'height': 678,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'jumbo',
#    'subtype': 'jumbo',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-jumbo.jpg',
#    'width': 1024},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'superJumbo',
#    'height': 1302,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'superJumbo',
#    'subtype': 'superJumbo',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-superJumbo.jpg',
#    'width': 1965},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blog225',
#    'height': 149,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blog225',
#    'subtype': 'blog225',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-blog225.jpg',
#    'width': 225},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master1050',
#    'height': 696,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master1050',
#    'subtype': 'master1050',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-master1050.jpg',
#    'width': 1050},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master675',
#    'height': 447,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master675',
#    'subtype': 'master675',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-master675.jpg',
#    'width': 675},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master495',
#    'height': 328,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master495',
#    'subtype': 'master495',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-master495.jpg',
#    'width': 495},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master180',
#    'height': 119,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master180',
#    'subtype': 'master180',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-master180.jpg',
#    'width': 180},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master315',
#    'height': 209,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master315',
#    'subtype': 'master315',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-master315.jpg',
#    'width': 315},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'master768',
#    'height': 509,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'master768',
#    'subtype': 'master768',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-master768.jpg',
#    'width': 768},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'thumbStandard',
#    'height': 75,
#    'legacy': {'thumbnail': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-thumbStandard.jpg',
#     'thumbnailheight': 75,
#     'thumbnailwidth': 75},
#    'rank': 0,
#    'subType': 'thumbnail',
#    'subtype': 'thumbnail',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-thumbStandard.jpg',
#    'width': 75},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blogSmallThumb',
#    'height': 50,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blogSmallThumb',
#    'subtype': 'blogSmallThumb',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-blogSmallThumb.jpg',
#    'width': 50},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'thumbLarge',
#    'height': 150,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'thumbLarge',
#    'subtype': 'thumbLarge',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-thumbLarge.jpg',
#    'width': 150},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'smallSquare168',
#    'height': 168,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'smallSquare168',
#    'subtype': 'smallSquare168',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-smallSquare168.jpg',
#    'width': 168},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'smallSquare252',
#    'height': 252,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'smallSquare252',
#    'subtype': 'smallSquare252',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-smallSquare252.jpg',
#    'width': 252},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'square320',
#    'height': 320,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'square320',
#    'subtype': 'square320',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-square320.jpg',
#    'width': 320},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'moth',
#    'height': 151,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'moth',
#    'subtype': 'moth',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-moth.jpg',
#    'width': 151},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'filmstrip',
#    'height': 190,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'filmstrip',
#    'subtype': 'filmstrip',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-filmstrip.jpg',
#    'width': 190},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'square640',
#    'height': 640,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'square640',
#    'subtype': 'square640',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-square640.jpg',
#    'width': 640},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumSquare149',
#    'height': 149,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumSquare149',
#    'subtype': 'mediumSquare149',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-mediumSquare149.jpg',
#    'width': 149},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'sfSpan',
#    'height': 263,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'sfSpan',
#    'subtype': 'sfSpan',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-sfSpan.jpg',
#    'width': 395},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'largeHorizontal375',
#    'height': 250,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'largeHorizontal375',
#    'subtype': 'largeHorizontal375',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-largeHorizontal375.jpg',
#    'width': 375},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'largeHorizontalJumbo',
#    'height': 683,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'largeHorizontalJumbo',
#    'subtype': 'largeHorizontalJumbo',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-largeHorizontalJumbo.jpg',
#    'width': 1024},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'horizontalMediumAt2X',
#    'height': 1302,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'horizontalMediumAt2X',
#    'subtype': 'horizontalMediumAt2X',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-horizontalMediumAt2X.jpg',
#    'width': 1953},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'hpLarge',
#    'height': 288,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'hpLarge',
#    'subtype': 'hpLarge',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-hpLarge.jpg',
#    'width': 511},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'largeWidescreen573',
#    'height': 323,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'largeWidescreen573',
#    'subtype': 'largeWidescreen573',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-largeWidescreen573.jpg',
#    'width': 573},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'largeWidescreen1050',
#    'height': 591,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'largeWidescreen1050',
#    'subtype': 'largeWidescreen1050',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-largeWidescreen1050.jpg',
#    'width': 1050},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'thumbWide',
#    'height': 126,
#    'legacy': {'wide': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-thumbWide.jpg',
#     'wideheight': 126,
#     'widewidth': 190},
#    'rank': 0,
#    'subType': 'wide',
#    'subtype': 'wide',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-thumbWide.jpg',
#    'width': 190},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoThumb',
#    'height': 50,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoThumb',
#    'subtype': 'videoThumb',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoThumb.jpg',
#    'width': 75},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoLarge',
#    'height': 507,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoLarge',
#    'subtype': 'videoLarge',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoLarge.jpg',
#    'width': 768},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumThreeByTwo210',
#    'height': 140,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumThreeByTwo210',
#    'subtype': 'mediumThreeByTwo210',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-mediumThreeByTwo210.jpg',
#    'width': 210},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumThreeByTwo225',
#    'height': 150,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumThreeByTwo225',
#    'subtype': 'mediumThreeByTwo225',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-mediumThreeByTwo225.jpg',
#    'width': 225},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumThreeByTwo440',
#    'height': 293,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumThreeByTwo440',
#    'subtype': 'mediumThreeByTwo440',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-mediumThreeByTwo440.jpg',
#    'width': 440},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumThreeByTwo252',
#    'height': 168,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumThreeByTwo252',
#    'subtype': 'mediumThreeByTwo252',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-mediumThreeByTwo252.jpg',
#    'width': 252},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumThreeByTwo378',
#    'height': 252,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumThreeByTwo378',
#    'subtype': 'mediumThreeByTwo378',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-mediumThreeByTwo378.jpg',
#    'width': 378},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'threeByTwoLargeAt2X',
#    'height': 1302,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'threeByTwoLargeAt2X',
#    'subtype': 'threeByTwoLargeAt2X',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-threeByTwoLargeAt2X.jpg',
#    'width': 1953},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'threeByTwoMediumAt2X',
#    'height': 1000,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'threeByTwoMediumAt2X',
#    'subtype': 'threeByTwoMediumAt2X',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-threeByTwoMediumAt2X.jpg',
#    'width': 1500},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'threeByTwoSmallAt2X',
#    'height': 400,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'threeByTwoSmallAt2X',
#    'subtype': 'threeByTwoSmallAt2X',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-threeByTwoSmallAt2X.jpg',
#    'width': 600},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'articleInline',
#    'height': 126,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'articleInline',
#    'subtype': 'articleInline',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-articleInline.jpg',
#    'width': 190},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'hpSmall',
#    'height': 108,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'hpSmall',
#    'subtype': 'hpSmall',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-hpSmall.jpg',
#    'width': 163},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'blogSmallInline',
#    'height': 100,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'blogSmallInline',
#    'subtype': 'blogSmallInline',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-blogSmallInline.jpg',
#    'width': 151},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mediumFlexible177',
#    'height': 117,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mediumFlexible177',
#    'subtype': 'mediumFlexible177',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-mediumFlexible177.jpg',
#    'width': 177},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSmall',
#    'height': 281,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSmall',
#    'subtype': 'videoSmall',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSmall.jpg',
#    'width': 500},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoHpMedium',
#    'height': 211,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoHpMedium',
#    'subtype': 'videoHpMedium',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoHpMedium.jpg',
#    'width': 375},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine600',
#    'height': 338,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine600',
#    'subtype': 'videoSixteenByNine600',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine600.jpg',
#    'width': 600},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine540',
#    'height': 304,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine540',
#    'subtype': 'videoSixteenByNine540',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine540.jpg',
#    'width': 540},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine495',
#    'height': 278,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine495',
#    'subtype': 'videoSixteenByNine495',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine495.jpg',
#    'width': 495},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine390',
#    'height': 219,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine390',
#    'subtype': 'videoSixteenByNine390',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine390.jpg',
#    'width': 390},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine1050',
#    'height': 591,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine1050',
#    'subtype': 'videoSixteenByNine1050',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine1050.jpg',
#    'width': 1050},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine480',
#    'height': 270,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine480',
#    'subtype': 'videoSixteenByNine480',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine480.jpg',
#    'width': 480},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine310',
#    'height': 174,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine310',
#    'subtype': 'videoSixteenByNine310',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine310.jpg',
#    'width': 310},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine225',
#    'height': 126,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine225',
#    'subtype': 'videoSixteenByNine225',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine225.jpg',
#    'width': 225},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine96',
#    'height': 54,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine96',
#    'subtype': 'videoSixteenByNine96',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine96.jpg',
#    'width': 96},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine768',
#    'height': 432,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine768',
#    'subtype': 'videoSixteenByNine768',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine768.jpg',
#    'width': 768},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNine150',
#    'height': 84,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNine150',
#    'subtype': 'videoSixteenByNine150',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNine150.jpg',
#    'width': 150},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoSixteenByNineJumbo1600',
#    'height': 901,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoSixteenByNineJumbo1600',
#    'subtype': 'videoSixteenByNineJumbo1600',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoSixteenByNineJumbo1600.jpg',
#    'width': 1600},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'miniMoth',
#    'height': 70,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'miniMoth',
#    'subtype': 'miniMoth',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-miniMoth.jpg',
#    'width': 151},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'windowsTile336H',
#    'height': 336,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'windowsTile336H',
#    'subtype': 'windowsTile336H',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-windowsTile336H.jpg',
#    'width': 694},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'videoFifteenBySeven1305',
#    'height': 609,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'videoFifteenBySeven1305',
#    'subtype': 'videoFifteenBySeven1305',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-videoFifteenBySeven1305.jpg',
#    'width': 1305},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'facebookJumbo',
#    'height': 549,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'facebookJumbo',
#    'subtype': 'facebookJumbo',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-facebookJumbo.jpg',
#    'width': 1050},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'watch308',
#    'height': 348,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'watch308',
#    'subtype': 'watch308',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-watch308.jpg',
#    'width': 312},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'watch268',
#    'height': 303,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'watch268',
#    'subtype': 'watch268',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-watch268.jpg',
#    'width': 272},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'verticalTwoByThree735',
#    'height': 1103,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'verticalTwoByThree735',
#    'subtype': 'verticalTwoByThree735',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-verticalTwoByThree735.jpg',
#    'width': 735},
#   {'caption': None,
#    'credit': None,
#    'crop_name': 'mobileMasterAt3x',
#    'height': 1193,
#    'legacy': {},
#    'rank': 0,
#    'subType': 'mobileMasterAt3x',
#    'subtype': 'mobileMasterAt3x',
#    'type': 'image',
#    'url': 'images/2020/01/28/science/28BRODYOPTIMISM/28BRODYOPTIMISM-mobileMasterAt3x.jpg',
#    'width': 1800}],
#  'news_desk': 'Well',
#  'pub_date': '2020-01-30T16:05:25+0000',
#  'section_name': 'Well',
#  'snippet': 'Test your knowledge of this week’s health news.',
#  'source': 'The New York Times',
#  'subsection_name': 'Live',
#  'type_of_material': 'Interactive Feature',
#  'uri': 'nyt://interactive/669ba0d2-a0c6-5f87-9017-c92d47cf3b20',
#  'web_url': 'https://www.nytimes.com/interactive/2020/01/30/well/live/31healthquiz-01312020.html',
#  'word_count': 0}

# %%
def format_articles(unformatted_docs):
    '''
    This function takes in a list of documents returned by the NYT api 
    and parses the documents into a list of dictionaries, 
    with 'id', 'header', and 'date' keys
    '''
    formatted = []
    for i in unformatted_docs:
        dic = {}
        dic['id'] = i['_id']
        dic['headline'] = i['headline']['main']
        dic['date'] = i['pub_date'][0:10]  # cutting time of day.
        formatted.append(dic)
    return(formatted)

# %%
all_formatted = format_articles(all_docs)

# %%
all_formatted[:5]
# Out:
# [{'date': '2020-01-30',
#   'headline': 'Weekly Health Quiz: Optimism, Muscles and Coronavirus',
#   'id': 'nyt://interactive/669ba0d2-a0c6-5f87-9017-c92d47cf3b20'},
#  {'date': '2020-01-28',
#   'headline': 'Coronavirus World Map: Tracking the Global Outbreak',
#   'id': 'nyt://interactive/e60f3741-87f7-531d-9e65-f73b61ffd30c'},
#  {'date': '2020-01-30',
#   'headline': 'A Virus’s Journey Across China',
#   'id': 'nyt://article/217bd4ba-d91e-5c4b-8926-71d190808e6e'},
#  {'date': '2020-01-31',
#   'headline': 'State Department Warns Against Traveling to China Amid Coronavirus Outbreak',
#   'id': 'nyt://article/27fd86f0-c453-54ef-b806-143bb6111f4e'},
#  {'date': '2020-01-30',
#   'headline': 'Wall St. Shrugs Off Risks Related to Viral Outbreak in China',
#   'id': 'nyt://article/9d4aca5a-7332-595b-8be2-587009cf9725'}]

# %% [markdown]
# ### Challenge 4: Collect more fields
# Edit the function above so that we include the lead_paragraph and word_count fields.
#
# HINT: Some articles may not contain a lead_paragraph, in which case, it'll throw an error if you try to address this value (which doesn't exist.) You need to add a conditional statement that takes this into consideration. If
#
# Advanced: Add another key that returns a list of keywords associated with the article.

# %%
def format_articles(unformatted_docs):
    '''
    This function takes in a list of documents returned by the NYT api 
    and parses the documents into a list of dictionaries, 
    with 'id', 'header', 'date', 'lead paragrph' and 'word count' keys
    '''
    formatted = []
    for i in unformatted_docs:
        dic = {}
        dic['id'] = i['_id']
        dic['headline'] = i['headline']['main']
        dic['date'] = i['pub_date'][0:10]  # cutting time of day.

        # YOUR CODE HERE
        
        if 'lead_paragraph' in i.keys():
            dic['lead_paragraph'] = i['lead_paragraph']
        dic['word_count'] = i['word_count']
        dic['keywords'] = [keyword['value'] for keyword in i['keywords']]

        formatted.append(dic)
        
    return(formatted)

# %%
all_formatted = format_articles(all_docs)
all_formatted[:5]
# Out:
# [{'date': '2020-01-30',
#   'headline': 'Weekly Health Quiz: Optimism, Muscles and Coronavirus',
#   'id': 'nyt://interactive/669ba0d2-a0c6-5f87-9017-c92d47cf3b20',
#   'keywords': ['Coronavirus (2019-nCoV)',
#    "Alzheimer's Disease",
#    'SARS (Severe Acute Respiratory Syndrome)',
#    'Prostate Gland',
#    'Heart',
#    'Elderly',
#    'Longevity',
#    'Hygiene and Cleanliness',
#    'Muscles',
#    'Deaths (Fatalities)',
#    'Medicine and Health',
#    'Optimism',
#    'Exercise'],
#   'lead_paragraph': 'Test your knowledge of this week’s health news.',
#   'word_count': 0},
#  {'date': '2020-01-28',
#   'headline': 'Coronavirus World Map: Tracking the Global Outbreak',
#   'id': 'nyt://interactive/e60f3741-87f7-531d-9e65-f73b61ffd30c',
#   'keywords': ['Coronavirus (2019-nCoV)',
#    'Epidemics',
#    'Centers for Disease Control and Prevention',
#    'Johns Hopkins University',
#    'Wuhan (China)',
#    'China',
#    'United States',
#    'Australia',
#    'Singapore',
#    'Disease Rates',
#    'Deaths (Fatalities)'],
#   'lead_paragraph': 'The virus has infected more than 116,500,500 people and has been detected in nearly every country.',
#   'word_count': 0},
#  {'date': '2020-01-30',
#   'headline': 'A Virus’s Journey Across China',
#   'id': 'nyt://article/217bd4ba-d91e-5c4b-8926-71d190808e6e',
#   'keywords': ['Coronavirus (2019-nCoV)',
#    'Protective Clothing and Gear',
#    'Beijing (China)',
#    'China',
#    'Epidemics',
#    'Respiratory Diseases'],
#   'lead_paragraph': 'Listen and subscribe to our podcast from your mobile device:Via Apple Podcasts | Via Spotify | Via Stitcher',
#   'word_count': 280},
#  {'date': '2020-01-31',
#   'headline': 'State Department Warns Against Traveling to China Amid Coronavirus Outbreak',
#   'id': 'nyt://article/27fd86f0-c453-54ef-b806-143bb6111f4e',
#   'keywords': ['Coronavirus (2019-nCoV)',
#    'China',
#    'Travel Warnings',
#    'Epidemics',
#    'State Department',
#    'Pompeo, Mike',
#    'World Health Organization',
#    'United States Politics and Government',
#    'United States International Relations'],
#   'lead_paragraph': 'The State Department on Thursday night issued an advisory telling Americans not to travel to China because of the public health threat posed by the coronavirus, as world health officials grappled with the expanding footprint of the outbreak.',
#   'word_count': 485},
#  {'date': '2020-01-30',
#   'headline': 'Wall St. Shrugs Off Risks Related to Viral Outbreak in China',
#   'id': 'nyt://article/9d4aca5a-7332-595b-8be2-587009cf9725',
#   'keywords': ['Stocks and Bonds',
#    'China',
#    'Economic Conditions and Trends',
#    'Coronavirus (2019-nCoV)',
#    'United States Economy',
#    'Factories and Manufacturing',
#    "Standard & Poor's 500-Stock Index"],
#   'lead_paragraph': 'Wall Street shook off growing fears that a mysterious and fast-moving virus in China could hurt the global economy, even as international markets were hit by those concerns on Thursday.',
#   'word_count': 586}]

# %% [markdown]
# ## 5. Exporting

# %%
keys = all_formatted[1]
# writing the rest
with open('all-formated.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(all_formatted)
